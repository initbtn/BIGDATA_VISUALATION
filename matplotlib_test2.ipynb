# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#파이차트 한글 사용 설정 방법
from matplotlib import rc, font_manager
fontname="C:/Windows/Fonts/H2GTRE.TTF"
#C:/Windows/Fonts/BMYEONSUNG_ttf.ttf
font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/H2GTRE.TTF").get_name()
rc('font',family=font_name)

# %%
#subplot
plt.figure()
plt.subplot(2,2,1)      #subplot( rows, cols, index)
plt.plot([1,2,3,4],[10,20,30,40])
plt.subplot(2,2,2)
plt.plot([10,20,30,40],[10,20,30,40])
plt.subplot(2,2,3)
plt.plot([100,200,300,400],[10,20,30,40])
plt.subplot(2,2,4)
plt.plot([11,12,30,40],[10,20,30,40])

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('matplotlib 활용')
plt.text(2.5, 3.0,'평균:2.5')       #그래프의 지정위치에 문자열 표시
plt.grid(True)
plt.show()

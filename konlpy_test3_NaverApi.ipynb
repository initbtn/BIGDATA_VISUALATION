# %% [markdown]
# # 한글 자연어 처리(한글 분석)

# %%
from konlpy.tag import *
Hannanum = Hannanum()
import konlpy
konlpy.__version__
# Out:
# '0.6.0'

# %% [markdown]
# ### 2. 네이버 API 요청하기
#
# - https://developers.naver.com/docs/serviceapi/search/blog/blog.md#python
#
# ```python
# # 네이버 검색 API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"
# encText = urllib.parse.quote("검색할 단어")
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)
# ```

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

# %%
client_id = "QRXFDasoyj1rbiN4mcXS"
client_secret = "erdIU8ADUj"

encText = urllib.parse.quote("제주한달살기")    #검색어 입력
display

url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display='+ str(100)  # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

# %%
request = urllib.request.Request(url)       # 요청 객체 생성

#request 헤더에 클라이언트 ID, SecretKey 추가
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

#서버 요청
response = urllib.request.urlopen(request)

#응답 결과 처리
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:38:59 +0900",
# 	"total":174489,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"<b>제주한달살기<\/b> 동쪽여행 구좌 가볼만한곳 송당리 카레 맛집... ",
# 			"link":"https:\/\/blog.naver.com\/ljyy5\/223155444029",
# 			"description":"[<b>제주 한 달 살기<\/b>] 동쪽 여행 구좌읍 가볼 만한 곳 송당리 카레 맛집 섭섭이네 피톤치드 가득 뿜어내는... 요리조리 찾아보니 송당리에 아기자기하고 제주스러운 카레 맛집 섭섭이네가 눈에 들어왔다. 그렇게... ",
# 			"bloggername":"Jamie’s Life",
# 			"bloggerlink":"blog.naver.com\/ljyy5",
# 			"postdate":"20230713"
# 		},
# 		{
# 			"title":"<b>제주 한달살기<\/b> 숙소 추천 - 제주도 오션뷰 원룸 amonthstrip",
# 			"link":"https:\/\/blog.naver.com\/blueseahee\/223063386488",
# 			"description":"살기 계획하고 있으시다면 amonthstrip 원룸 추천드려요!! #amonthstrip #제주살이 #<b>제주한달살기<\/b>숙소 #제주단기임대 #<b>제주한달살기<\/b> #제주숙소 #숙소임대 #제주숙소임대 #제주원룸 #한달살기 #제주 #제주도 #제주여행",
# 			"bloggername":"물꼬기의 육아사묘",
# 			"bloggerlink":"blog.naver.com\/blueseahee",
# 			"postdate":"20230403"
# 		},
# 		{
# ...

# %%
import json

res_body=json.loads(response_body.decode('utf-8'))
print(res_body['items'])
# Out:
# [{'title': '<b>제주한달살기</b> 동쪽여행 구좌 가볼만한곳 송당리 카레 맛집... ', 'link': 'https://blog.naver.com/ljyy5/223155444029', 'description': '[<b>제주 한 달 살기</b>] 동쪽 여행 구좌읍 가볼 만한 곳 송당리 카레 맛집 섭섭이네 피톤치드 가득 뿜어내는... 요리조리 찾아보니 송당리에 아기자기하고 제주스러운 카레 맛집 섭섭이네가 눈에 들어왔다. 그렇게... ', 'bloggername': 'Jamie’s Life', 'bloggerlink': 'blog.naver.com/ljyy5', 'postdate': '20230713'}, {'title': '<b>제주 한달살기</b> 숙소 추천 - 제주도 오션뷰 원룸 amonthstrip', 'link': 'https://blog.naver.com/blueseahee/223063386488', 'description': '살기 계획하고 있으시다면 amonthstrip 원룸 추천드려요!! #amonthstrip #제주살이 #<b>제주한달살기</b>숙소 #제주단기임대 #<b>제주한달살기</b> #제주숙소 #숙소임대 #제주숙소임대 #제주원룸 #한달살기 #제주 #제주도 #제주여행', 'bloggername': '물꼬기의 육아사묘', 'bloggerlink': 'blog.naver.com/blueseahee', 'postdate': '20230403'}, {'title': '[돌아기와 <b>제주</b>도 <b>한달살기</b>]DAY23. <b>제주</b> 해장국 맛집... ', 'link': 'https://blog.naver.com/lovelylaani/223150966051', 'description': '#제주도한달살기 #<b>제주한달살기</b> #제주도아기랑 #제주도돌아기 #제주도해장국맛집 #제주도해장국추천 #숙성도본점 #숙성도본점예약 #숙성도본점테이블링 #숙성도본점메뉴추천 #숙성도본점대기시간... ', 'bloggername': '
# ...

# %%
str1=''
for item in res_body['items']:
    str1+=item['description']
    print('title: ', item['title'])
    print('description: ', item['description'])
# Out:
# title:  <b>제주한달살기</b> 동쪽여행 구좌 가볼만한곳 송당리 카레 맛집...
# description:  [<b>제주 한 달 살기</b>] 동쪽 여행 구좌읍 가볼 만한 곳 송당리 카레 맛집 섭섭이네 피톤치드 가득 뿜어내는... 요리조리 찾아보니 송당리에 아기자기하고 제주스러운 카레 맛집 섭섭이네가 눈에 들어왔다. 그렇게...
# title:  <b>제주 한달살기</b> 숙소 추천 - 제주도 오션뷰 원룸 amonthstrip
# description:  살기 계획하고 있으시다면 amonthstrip 원룸 추천드려요!! #amonthstrip #제주살이 #<b>제주한달살기</b>숙소 #제주단기임대 #<b>제주한달살기</b> #제주숙소 #숙소임대 #제주숙소임대 #제주원룸 #한달살기 #제주 #제주도 #제주여행
# title:  [돌아기와 <b>제주</b>도 <b>한달살기</b>]DAY23. <b>제주</b> 해장국 맛집...
# description:  #제주도한달살기 #<b>제주한달살기</b> #제주도아기랑 #제주도돌아기 #제주도해장국맛집 #제주도해장국추천 #숙성도본점 #숙성도본점예약 #숙성도본점테이블링 #숙성도본점메뉴추천 #숙성도본점대기시간...
# title:  [<b>제주한달살기</b>] 아자탐험대 체험, 엄마는 휴식시간이었던...
# description:  2022년 여름 <b>제주한달살기</b> #<b>제주한달살기</b> 다녀온지 어느새 1년!! 우리 아이들은 여전히 “엄마 제주도 또... 특히 한달살기처럼 오래도록 제주여행중이라면 한번쯤 부모에게도 꼭 필요한 체험이라 생각해보며...
# title:  여행이좋다 :: 대망의 <b>제주 한달살기</b> 마지막 날 30일째
# description:  다녀온 <b>제주 한 달 살기</b> 마지막 날을 정리해 볼까 합니다. 오후 5시쯤 제주에서 육지로 나가는 배편을... 그럼 그동안 재미없는 후기 읽으시느라 수고하셨고, 다른 지역의 다음 한 달 살기로 찾아뵙도록...
# ...

# %%
str1
# Out:
# "[<b>제주 한 달 살기</b>] 동쪽 여행 구좌읍 가볼 만한 곳 송당리 카레 맛집 섭섭이네 피톤치드 가득 뿜어내는... 요리조리 찾아보니 송당리에 아기자기하고 제주스러운 카레 맛집 섭섭이네가 눈에 들어왔다. 그렇게... 살기 계획하고 있으시다면 amonthstrip 원룸 추천드려요!! #amonthstrip #제주살이 #<b>제주한달살기</b>숙소 #제주단기임대 #<b>제주한달살기</b> #제주숙소 #숙소임대 #제주숙소임대 #제주원룸 #한달살기 #제주 #제주도 #제주여행#제주도한달살기 #<b>제주한달살기</b> #제주도아기랑 #제주도돌아기 #제주도해장국맛집 #제주도해장국추천 #숙성도본점 #숙성도본점예약 #숙성도본점테이블링 #숙성도본점메뉴추천 #숙성도본점대기시간... 2022년 여름 <b>제주한달살기</b> #<b>제주한달살기</b> 다녀온지 어느새 1년!! 우리 아이들은 여전히 “엄마 제주도 또... 특히 한달살기처럼 오래도록 제주여행중이라면 한번쯤 부모에게도 꼭 필요한 체험이라 생각해보며... 다녀온 <b>제주 한 달 살기</b> 마지막 날을 정리해 볼까 합니다. 오후 5시쯤 제주에서 육지로 나가는 배편을... 그럼 그동안 재미없는 후기 읽으시느라 수고하셨고, 다른 지역의 다음 한 달 살기로 찾아뵙도록... 내년에 제주도에 오면 꼭 가야할곳 #호자 #성산물고기자리 #꼬스뗀뇨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 내가 홍보하고 다니는 제주성산3대맛집ㅋㅋㅋ #엄마랑아이랑제주에서한달 #아이랑<b>제주한달살기</b>장마 사이에서 만난 멋진 광덕산 정상뷰 제주한달살이 동안 5번의 한라산 산행 계획이었지만 2번으로 끝난 아쉬움을 싸~~~악, 이번 <b>제주한달살기</b>는 어차피 옆지기 수술 후 회복과 안정, 쉼이 목적이었으니... 나는 못다한 일이 있어 비행기표를 저녁시간으로 바꿨다 애당초 제주올레를 이렇게 열심히 할 계획은... ' ^^ 올레패스 4월 이벤트 참가해서 상품권 받아 교환한 자석이랑 머그컵 그리고 과즐^^ <b>제주한달살기</b>... 하며 제주도 올레길 
# ...

# %% [markdown]
# ### 2.2 이미지 불러와서 저장하기

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "QRXFDasoyj1rbiN4mcXS"
client_secret = "erdIU8ADUj"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/image?query=" + encText + '&display=' + str(100) # JSON 결과
# url = "https://openapi.naver.com/v1/search/image.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 14 Jul 2023 12:38:59 +0900",
# 	"total":135152,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"[Googletrans] Googletrans를 이용한 파이썬 번역 프로그램 만들기",
# 			"link":"http:\/\/post.phinf.naver.net\/MjAyMzA1MTJfMTg2\/MDAxNjgzODU0MDk1MTk0.2KGWGondEPBAMtpDp1jxZ8K_-B5PyXBpbFrUyLJJSDgg.RCGYjeAeSN99nsBzQYdD3r8x_mnxp-7IVcz6ruttuJUg.PNG\/Ia0PoKX1IQZA6S5K67AetaSTTmzA.jpg",
# 			"thumbnail":"https:\/\/search.pstatic.net\/common\/?type=b150&src=http:\/\/post.phinf.naver.net\/MjAyMzA1MTJfMTg2\/MDAxNjgzODU0MDk1MTk0.2KGWGondEPBAMtpDp1jxZ8K_-B5PyXBpbFrUyLJJSDgg.RCGYjeAeSN99nsBzQYdD3r8x_mnxp-7IVcz6ruttuJUg.PNG\/Ia0PoKX1IQZA6S5K67AetaSTTmzA.jpg",
# 			"sizeheight":"537",
# 			"sizewidth":"797"
# 		},
# 		{
# 			"title":"Python Beginners Tutorial in 2023 | Tutorial, Beginners guide, Beginners",
# 			"link":"https:\/\/i.pinimg.com\/originals\/13\/fe\/92\/13fe92c595dcd87fc71c33b4f32770ca.jpg",
# ...

# %%
import json

res_body=json.loads(response_body.decode('utf-8'))
print(res_body['items'])
# Out:
# [{'title': '[Googletrans] Googletrans를 이용한 파이썬 번역 프로그램 만들기', 'link': 'http://post.phinf.naver.net/MjAyMzA1MTJfMTg2/MDAxNjgzODU0MDk1MTk0.2KGWGondEPBAMtpDp1jxZ8K_-B5PyXBpbFrUyLJJSDgg.RCGYjeAeSN99nsBzQYdD3r8x_mnxp-7IVcz6ruttuJUg.PNG/Ia0PoKX1IQZA6S5K67AetaSTTmzA.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://post.phinf.naver.net/MjAyMzA1MTJfMTg2/MDAxNjgzODU0MDk1MTk0.2KGWGondEPBAMtpDp1jxZ8K_-B5PyXBpbFrUyLJJSDgg.RCGYjeAeSN99nsBzQYdD3r8x_mnxp-7IVcz6ruttuJUg.PNG/Ia0PoKX1IQZA6S5K67AetaSTTmzA.jpg', 'sizeheight': '537', 'sizewidth': '797'}, {'title': 'Python Beginners Tutorial in 2023 | Tutorial, Beginners guide, Beginners', 'link': 'https://i.pinimg.com/originals/13/fe/92/13fe92c595dcd87fc71c33b4f32770ca.jpg', 'thumbnail': 'https://search.pstatic.net/sunny/?type=b150&src=https://i.pinimg.com/originals/13/fe/92/13fe92c595dcd87fc71c33b4f32770ca.jpg', 'sizeheight': '546', 'sizewidth': '970'}, {'title': '아유, 파이썬 좋다. | 유머 게시판 | 루리웹', 'link': 'https://i2.ruliweb.com/img/
# ...

# %%
for item in res_body['items']:

# %%
img_link_list=[]
link_title = []
for item in res_body['items']:
    link_title.append(item['title'])
    link_title.append(item['link'])
    img_link_list.append(link_title)
    link_title = []
    # print('title: ', item['title'])
    # print('description: ', item['description'])

img_link_list
# Out:
# [['[Googletrans] Googletrans를 이용한 파이썬 번역 프로그램 만들기',
#   'http://post.phinf.naver.net/MjAyMzA1MTJfMTg2/MDAxNjgzODU0MDk1MTk0.2KGWGondEPBAMtpDp1jxZ8K_-B5PyXBpbFrUyLJJSDgg.RCGYjeAeSN99nsBzQYdD3r8x_mnxp-7IVcz6ruttuJUg.PNG/Ia0PoKX1IQZA6S5K67AetaSTTmzA.jpg'],
#  ['Python Beginners Tutorial in 2023 | Tutorial, Beginners guide, Beginners',
#   'https://i.pinimg.com/originals/13/fe/92/13fe92c595dcd87fc71c33b4f32770ca.jpg'],
#  ['아유, 파이썬 좋다. | 유머 게시판 | 루리웹',
#   'https://i2.ruliweb.com/img/20/09/27/174ce37ee2c4d3f8a.jpg'],
#  ['프리보드 - 파이썬 또또 질문) 불현듯 실마리가 보일 거 같은데 - BATTLEPAGE.COM v12 BATTLEPAGE.COM v12',
#   'http://img.battlepage.com/upload/2020/0607/071808394521b72aea65c7f87d64b439cb9b732c.png'],
#  ['파이썬 뭔가 이름 야하지 않냐 :: 웃긴대학 대기자료 파이썬 뭔가 이름 야하지 않냐',
#   'http://down.humoruniv.com/hwiparambbs/data/pdswait/a_wb1f87b001_a731bc309623b9a8451a06e121ef8c51c949e556.png'],
#  ['(파이썬 질문) 웹크롤링중 태그가 없는 항목을 골라내다 막혔습니다 : 클리앙',
#   'https://cdn.clien.net/web/api/file/F01/9095356/4163d36c4b71d2.png'],
# ...

# %%
i=1
for link,title in img_link_list:
    save_name='data/imges/img'+title+str(i)+'.jpg'
    try:
        urllib.request.urlretrieve(link, save_name)
        print(link, '저장됨')
        i+=1
    except:
        print(link, '저장실패')

# %%
from konlpy.tag import *
hannanum=Hannanum()
kkma=Kkma()
komoran=Komoran()
okt=Okt()

# %% [markdown]
# #### 3.1. 형태소 분석기 공통적 기능
# - __nouns__      : 명사 추출
# - __mprphs__    : 형태 추출
# - __pos__          : 형태소 추출과 품사 태깅

# %%
from nltk import Text
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc

# %%
fontname='c:/Windows/Fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=fontname).get_name()
rc('font',family=font_name)

# %%
from collections import Counter

# %%
nouns_news=okt.nouns(data)
counter=Counter(nouns_news)
counter2=dict()
for tag, count in counter.items():
    if (len(tag)>1) and (count>1):
        counter2[tag]=count

counter2
# Out:
# {'미국': 8,
#  '한국': 5,
#  '통화': 5,
#  '기준금리': 11,
#  '인상': 15,
#  '사이클': 3,
#  '연속': 4,
#  '동결': 6,
#  '사실': 2,
#  '긴축': 3,
#  '종료': 5,
#  '시장': 6,
#  '소비자': 2,
#  '물가': 3,
#  '예상': 3,
#  '둔화': 4,
#  '전망': 5,
#  '급증': 2,
#  '가계부채': 4,
#  '국제': 3,
#  '에너지': 3,
#  '가격': 3,
#  '변동성': 2,
#  '변수': 2,
#  '지적': 3,
#  '통화정책': 2,
#  '방향': 2,
#  '회의': 2,
#  '지난': 2,
#  '시작': 2,
#  '올해': 3,
#  '차례': 2,
#  '금리': 8,
#  '개월': 2,
#  '결정': 3,
#  '물가상승률': 2,
#  '흐름': 2,
#  '어가': 2,
#  '다시': 2,
#  '목표': 2,
#  '수준': 2,
#  '정책': 2,
#  '기조': 2,
#  '총재': 2,
#  '금융': 2,
#  '위원': 2,
#  '모두': 2,
#  '추가': 5,
#  '가능성': 6,
#  '시사': 2,
#  '인하': 2,
#  '지난달': 4,
#  '완화': 3,
#  '경기': 2,
#  '연방': 4,
#  '준비': 2,
#  '제도': 2,
#  '근원': 2,
#  '공개시장': 2,
#  '위원회': 2,
#  '마지막': 2,
#  '중국': 2,
#  '일본': 2,
#  '대출': 2,
#  '파월': 2,
#  '의장': 2,
#  '고용': 2,
#  '증가': 2,
#  '기자': 3}

# %%
from wordcloud import WordCloud
font_path='c:/Windows/Fonts/malgun.ttf'
wc=WordCloud(width=1000, height=800, background_color='white', font_path=font_path, random_state=0)
plt.imshow(wc.generate_from_frequencies(counter2))
plt.axis('off')
plt.savefig('data/wc1.png')
plt.show()

# %% [markdown]
# #### 4. pytagcloud 사용하여 그리기
#
# [한글서체 등록방법] https://velog.io/@ruinak_4127/PytagCloud

# %%
! pip install pygame
! pip install pytagcloud
! pip install simplejson
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# ...

# %%
import pytagcloud
count3=counter.most_common(50)
taglist=pytagcloud.make_tags(count3, maxsize=80)
taglist
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import pytagcloud
#       2 count3=counter.most_common(50)
#       3 taglist=pytagcloud.make_tags(count3, maxsize=80)
#
# File c:\Users\admin\anaconda3\lib\site-packages\pytagcloud\__init__.py:25
#      23 DEFAULT_FONT = 'Droid Sans'
#      24 DEFAULT_PALETTE = 'default'
# ---> 25 FONT_CACHE = simplejson.load(open(os.path.join(FONT_DIR, 'fonts.json'), 'r'))
#      27 pygame.init()
#      28 convsurf = Surface((2 * TAG_PADDING, 2 * TAG_PADDING))
#
# File c:\Users\admin\anaconda3\lib\site-packages\simplejson\__init__.py:452, in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     401 def load(fp, encoding=None, cls=None, object_hook=None, parse_float=None,
# ...

# %%
pytagcloud.create_tag_image(taglist, 'data/pycloud.png', size=(900,800),
                                      fontname='Korean', rectangular=False)
